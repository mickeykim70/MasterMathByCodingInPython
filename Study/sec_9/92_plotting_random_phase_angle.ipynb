# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
angls = np.random.randn(100)*2*np.pi

for i in angls:
    plt.plot( [0,np.cos(i)], [0,np.sin(i)])

plt.axis('square')
plt.axis([-1,1,-1,1])
plt.axis('off')
plt.show()
