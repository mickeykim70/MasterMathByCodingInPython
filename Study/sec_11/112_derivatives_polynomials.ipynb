# %%
import sympy as sym
import matplotlib.pyplot as plt
import numpy as np
from sympy import Derivative
from IPython.display import Math, display

# %%
x = sym.symbols('x')

fx = x**2

# Compute the derivatives
dfx = sym.diff(fx, x)

# %%
# Leibniz notation
display(Math('f(x) = %s, \\quad \\frac{df}{dx} = %s' %(sym.latex(fx), sym.latex(dfx)) ))
# Out:
# $\displaystyle f(x) = x^{2}, \quad \frac{df}{dx} = 2 x$

# %%
# Lagrange notation
display(Math('f(x) = %s, \\quad f\'=%s' %(sym.latex(fx), sym.latex(dfx))))
# Out:
# $\displaystyle f(x) = x^{2}, \quad f'=2 x$

# %%
# Newton notation
display(Math('f(x) = %s, \\quad \\dot{f}=%s' %(sym.latex(fx), sym.latex(dfx))))
# Out:
# $\displaystyle f(x) = x^{2}, \quad \dot{f}=2 x$

# %%
import sympy.plotting.plot as symplot

# %%
fx1 = 3 - x**3

p = symplot(fx1, (x,-5,5), show=False)
p.extend( symplot(sym.diff(fx1), (x,-5,5), show=False) )
p[1].line_color = 'r'
p[0].label = '$f(x) = %s$' %sym.latex(fx1)
p[1].label = '$f(x) = %s$' %sym.latex(sym.diff(fx1))

p.legend=True
p.xlim=[-3,3]
p.ylim=[-10,10]
p.show()
