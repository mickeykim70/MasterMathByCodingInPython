# %%
from opcode import jabs_op

import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from opcode import jabs_op
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'jabs_op' from 'opcode' (C:\Users\kimna\miniconda3\envs\physics_env\Lib\opcode.py)

# %%
z = 2 + 3j

plt.plot([0,z.real], [0,z.imag], 'r-')
plt.axis([-4,4, -4,4])
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 z = 2 + 3j
# ----> 3 plt.plot([0,z.real], [0,z.imag], 'r-')
#       4 plt.axis([-4,4, -4,4])
#       5 plt.grid(True)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ---
# ### Exercise
#
# $$z_1 = -3i$$
#
# $$z_2 = -1i$$
#
# graph z1 + z2, z1z2

# %%
z1 = -3 + 1j
z2 = -1 + 1j 

sum_z1z2 = z1 + z2
mul_z1z2 = z1 * z2

plt.plot([0,z1.real], [0,z1.imag], 'b-', label='z1')
plt.plot([0,z2.real], [0,z2.imag], 'r-', label='z2')
plt.plot([0,sum_z1z2.real], [0,sum_z1z2.imag], 'y-', label='z1+z2')
plt.plot([0,mul_z1z2.real], [0,mul_z1z2.imag], 'm-', label='z1*z2')


plt.axis([-5,5, -5,5])
plt.grid(True)
plt.legend()
plt.show()
